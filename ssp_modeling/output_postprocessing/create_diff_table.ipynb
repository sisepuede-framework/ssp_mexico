# %%
import pandas as pd
import numpy as np
import os

# %%
OUTPUT_POSTPROCESSING_DIR_PATH = os.getcwd()
SSP_MODELING_DIR_PATH = os.path.dirname(OUTPUT_POSTPROCESSING_DIR_PATH)
SSP_OUTPUT_DIR_PATH = os.path.join(SSP_MODELING_DIR_PATH, "ssp_run_output")
CW_DATA_DIR_PATH = os.path.join(OUTPUT_POSTPROCESSING_DIR_PATH, "data")

# %%
ISO3 = "MEX"
REGION_NAME = "mexico"
RUN_DIR_PATH = os.path.join(SSP_OUTPUT_DIR_PATH, "sisepuede_results_sisepuede_run_2025-09-30T11;28;10.980165")

# %% [markdown]
# ### Load emission targets and ssp outputs dfs

# %%
# Load emission targets
emission_targets_df = pd.read_csv(os.path.join(CW_DATA_DIR_PATH, "emission_targets_mexico_2022.csv"))
emission_targets_df.head()
# Out:
#   Subsector  Gas         Edgar_Class Edgar_Sector Edgar_Subsector  \
# 0      agrc  ch4      AG - Crops:CH4  Agriculture      AG - Crops
# 1      agrc  co2      AG - Crops:CO2  Agriculture      AG - Crops
# 2      agrc  n2o      AG - Crops:N2O  Agriculture      AG - Crops
# 3      lvst  ch4  AG - Livestock:CH4  Agriculture  AG - Livestock
# 4      lsmm  ch4  AG - Livestock:CH4  Agriculture  AG - Livestock
#
#   Edgar_Subsector_Synthetic  \
# 0                AG - Crops
# 1                AG - Crops
# 2                AG - Crops
# 3            AG - Livestock
# 4            AG - Livestock
#
#                                                 Vars         ids        MEX
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...  1:agrc:ch4   1.144799
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...  2:agrc:co2   2.938056
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...  3:agrc:n2o  29.452258
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  4:lvst:ch4  44.017738
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  5:lsmm:ch4  44.017738

# %%
# Load output data
ssp_output_df = pd.read_csv(os.path.join(RUN_DIR_PATH, 
                                         "sisepuede_results_sisepuede_run_2025-09-30T11;28;10.980165_WIDE_INPUTS_OUTPUTS.csv"))
ssp_output_df.head()
# Out:
#    primary_id  region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  mexico            0                    938860.188587
# 1           0  mexico            1                    942528.969886
# 2           0  mexico            2                    944066.850803
# 3           0  mexico            3                    942372.313186
# 4           0  mexico            4                    935865.150162
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             1.295621e+07           392567.842328            1.910190e+06
# 1             1.300684e+07           394101.878573            1.917654e+06
# 2             1.302806e+07           394744.916376            1.920783e+06
# 3             1.300468e+07           394036.375335            1.917336e+06
# 4             1.291488e+07           391315.519792            1.904096e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     19046.794337         271808.943979
# 1                                     19121.223441         272871.091019
# 2                                     19152.422657         273316.322155
# 3                                     19118.045323         272825.737416
# 4                                     18986.033553         270941.851901
#
#    area_agrc_crops_other_annual  ...  \
# 0                  2.848687e+06  ...
# 1                  2.859819e+06  ...
# 2                  2.864485e+06  ...
# 3                  2.859343e+06  ...
# 4                  2.839599e+06  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                         12.059233               2.946800
# 1                                         12.539800               3.455483
# 2                                         12.161233               3.041817
# 3                                         12.289167               3.375283
# 4                                         12.337700               2.992183
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       6.177415                                     0.0
# 1                       7.165802                                     0.0
# 2                      11.119348                                     0.0
# 3                       5.436126                                     0.0
# 4                       6.177415                                     0.0
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 2.755621               8.636027
# 1                 3.259699               8.228317
# 2                 3.958685               8.302446
# 3                 4.167037               8.846059
# 4                 3.226093               7.882382
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    73.140598                37.547100
# 1                    71.163825                39.000100
# 2                    89.448975                39.119475
# 3                    90.190264                37.352525
# 4                    84.012849                38.551850
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                              28.821448
# 1                              29.765171
# 2                              28.720595
# 3                              29.482348
# 4                              32.769776
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %% [markdown]
# ### Obtain the ssp output values in the emission targets format

# %%
def sum_vars_from_ssp_outputs(
    emission_targets_df: pd.DataFrame,
    ssp_outputs_df: pd.DataFrame,
    vars_col: str = "Vars",
    out_col: str = "ssp_total",
    record_missing_col: str | None = "missing_vars",
    ssp_filter: dict | None = None,
) -> pd.DataFrame:
    """
    For each row in emission_targets_df, split the colon-separated strings in `vars_col`,
    find those columns in ssp_outputs_df, sum their values (over rows & columns), and
    write the total to `out_col` in emission_targets_df.

    Parameters
    ----------
    emission_targets_df : DataFrame
        Must contain a string column `vars_col` with colon-separated names.
    ssp_outputs_df : DataFrame
        Wide table whose columns include the names referenced by `emission_targets_df[vars_col]`.
    vars_col : str
        Column in emission_targets_df with colon-separated variable names.
    out_col : str
        New column to create in emission_targets_df with totals from ssp_outputs_df.
    record_missing_col : str | None
        If provided, creates a column listing any missing vars for each row.
    df2_filter : dict | None
        Optional filters to reduce ssp_outputs_df before summing, e.g.
        {"region": "egypt", "time_period": 7}

    Returns
    -------
    DataFrame
        emission_targets_df with new column `out_col` (and `record_missing_col` if requested).
    """
    # Optionally filter ssp_outputs_df by key=value pairs (e.g., region/time_period)
    if ssp_filter:
        mask = pd.Series(True, index=ssp_outputs_df.index)
        for k, v in ssp_filter.items():
            mask &= (ssp_outputs_df[k] == v)
        ssp_view = ssp_outputs_df.loc[mask]
    else:
        ssp_view = ssp_outputs_df

    # Ensure we only operate on numeric data when summing
    numeric_cols = set(ssp_view.select_dtypes(include=[np.number]).columns)

    def _total_for_vars(vars_str: str):
        if pd.isna(vars_str) or not str(vars_str).strip():
            return np.nan, []

        # Split, strip, and deduplicate while preserving order
        raw = [s.strip() for s in str(vars_str).split(":") if s.strip()]
        seen = set()
        cols = [c for c in raw if not (c in seen or seen.add(c))]

        present = [c for c in cols if c in ssp_view.columns and c in numeric_cols]
        missing = [c for c in cols if c not in ssp_view.columns or c not in numeric_cols]

        if not present or ssp_view.empty:
            return np.nan, missing

        # Sum over all filtered rows & all present columns
        vals = ssp_view[present].to_numpy(dtype=float, copy=False)
        total = np.nansum(vals)
        return float(total), missing

    totals, missings = [], []
    for v in emission_targets_df[vars_col].astype("string"):
        total, missing = _total_for_vars(v)
        totals.append(total)
        missings.append(missing)

    emission_targets_df = emission_targets_df.copy()
    emission_targets_df[out_col] = totals
    if record_missing_col is not None:
        emission_targets_df[record_missing_col] = missings

    return emission_targets_df


# -----------------------------
# Example usage
# -----------------------------

# If DF2 has a single row for the target (e.g., region="egypt", a specific time_period):
# df2_filter = {"region": "egypt"}              # or {"region": "egypt", "time_period": 7}
# If you want to sum across all rows of DF2, set df2_filter = None.

# df1_result = sum_vars_from_df2(DF1, DF2, vars_col="Vars",
#                                out_col="DF2_total",
#                                record_missing_col="Missing_in_DF2",
#                                df2_filter={"region": "egypt"})
# print(df1_result.head())

# %%
ssp_output_df.head()
# Out:
#    primary_id  region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  mexico            0                    938860.188587
# 1           0  mexico            1                    942528.969886
# 2           0  mexico            2                    944066.850803
# 3           0  mexico            3                    942372.313186
# 4           0  mexico            4                    935865.150162
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             1.295621e+07           392567.842328            1.910190e+06
# 1             1.300684e+07           394101.878573            1.917654e+06
# 2             1.302806e+07           394744.916376            1.920783e+06
# 3             1.300468e+07           394036.375335            1.917336e+06
# 4             1.291488e+07           391315.519792            1.904096e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     19046.794337         271808.943979
# 1                                     19121.223441         272871.091019
# 2                                     19152.422657         273316.322155
# 3                                     19118.045323         272825.737416
# 4                                     18986.033553         270941.851901
#
#    area_agrc_crops_other_annual  ...  \
# 0                  2.848687e+06  ...
# 1                  2.859819e+06  ...
# 2                  2.864485e+06  ...
# 3                  2.859343e+06  ...
# 4                  2.839599e+06  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                         12.059233               2.946800
# 1                                         12.539800               3.455483
# 2                                         12.161233               3.041817
# 3                                         12.289167               3.375283
# 4                                         12.337700               2.992183
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       6.177415                                     0.0
# 1                       7.165802                                     0.0
# 2                      11.119348                                     0.0
# 3                       5.436126                                     0.0
# 4                       6.177415                                     0.0
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 2.755621               8.636027
# 1                 3.259699               8.228317
# 2                 3.958685               8.302446
# 3                 4.167037               8.846059
# 4                 3.226093               7.882382
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    73.140598                37.547100
# 1                    71.163825                39.000100
# 2                    89.448975                39.119475
# 3                    90.190264                37.352525
# 4                    84.012849                38.551850
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                              28.821448
# 1                              29.765171
# 2                              28.720595
# 3                              29.482348
# 4                              32.769776
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %%
emission_targets_df_extended = sum_vars_from_ssp_outputs(emission_targets_df, ssp_output_df, vars_col="Vars",
                               out_col="ssp_emission",
                               record_missing_col="missing_in_ssp_outputs",
                               ssp_filter={"region": REGION_NAME, "primary_id": 0, "time_period": 7})

emission_targets_df_extended.head()
# Out:
#   Subsector  Gas         Edgar_Class Edgar_Sector Edgar_Subsector  \
# 0      agrc  ch4      AG - Crops:CH4  Agriculture      AG - Crops
# 1      agrc  co2      AG - Crops:CO2  Agriculture      AG - Crops
# 2      agrc  n2o      AG - Crops:N2O  Agriculture      AG - Crops
# 3      lvst  ch4  AG - Livestock:CH4  Agriculture  AG - Livestock
# 4      lsmm  ch4  AG - Livestock:CH4  Agriculture  AG - Livestock
#
#   Edgar_Subsector_Synthetic  \
# 0                AG - Crops
# 1                AG - Crops
# 2                AG - Crops
# 3            AG - Livestock
# 4            AG - Livestock
#
#                                                 Vars         ids        MEX  \
# 0  emission_co2e_ch4_agrc_anaerobicdom_rice:emiss...  1:agrc:ch4   1.144799
# 1  emission_co2e_co2_agrc_biomass_bevs_and_spices...  2:agrc:co2   2.938056
# 2  emission_co2e_n2o_agrc_biomass_burning:emissio...  3:agrc:n2o  29.452258
# 3  emission_co2e_ch4_lvst_entferm_buffalo:emissio...  4:lvst:ch4  44.017738
# 4  emission_co2e_ch4_lsmm_anaerobic_digester:emis...  5:lsmm:ch4  44.017738
#
#    ssp_emission missing_in_ssp_outputs
# 0      0.673259                     []
# 1      0.965996                     []
# 2      6.111167                     []
# 3      1.150861                     []
# 4      0.105391                     []

# %% [markdown]
# ### Create diff report

# %%
# subset the emission targets to create the diff report template
diff_report_df = emission_targets_df_extended[[
    "Subsector",
    "Edgar_Class",
    ISO3,
    "ssp_emission",
]].copy()
diff_report_df.head()
# Out:
#   Subsector         Edgar_Class        MEX  ssp_emission
# 0      agrc      AG - Crops:CH4   1.144799      0.673259
# 1      agrc      AG - Crops:CO2   2.938056      0.965996
# 2      agrc      AG - Crops:N2O  29.452258      6.111167
# 3      lvst  AG - Livestock:CH4  44.017738      1.150861
# 4      lsmm  AG - Livestock:CH4  44.017738      0.105391

# %%
# merge subsector an id into a single column for clarity
diff_report_df["subsector_id"] = diff_report_df["Subsector"] + " - " + diff_report_df["Edgar_Class"]
diff_report_df = diff_report_df.drop(columns=["Subsector", "Edgar_Class"])
diff_report_df.head()
# Out:
#          MEX  ssp_emission               subsector_id
# 0   1.144799      0.673259      agrc - AG - Crops:CH4
# 1   2.938056      0.965996      agrc - AG - Crops:CO2
# 2  29.452258      6.111167      agrc - AG - Crops:N2O
# 3  44.017738      1.150861  lvst - AG - Livestock:CH4
# 4  44.017738      0.105391  lsmm - AG - Livestock:CH4

# %%
#rename region column
diff_report_df = diff_report_df.rename(columns={ISO3: "inventory_emission"})
diff_report_df.head()
# Out:
#    inventory_emission  ssp_emission               subsector_id
# 0            1.144799      0.673259      agrc - AG - Crops:CH4
# 1            2.938056      0.965996      agrc - AG - Crops:CO2
# 2           29.452258      6.111167      agrc - AG - Crops:N2O
# 3           44.017738      1.150861  lvst - AG - Livestock:CH4
# 4           44.017738      0.105391  lsmm - AG - Livestock:CH4

# %%
# Create inventory_share column
diff_report_df["inventory_share"] = diff_report_df["inventory_emission"] / diff_report_df["inventory_emission"].sum()
diff_report_df
# Out:
#     inventory_emission  ssp_emission                             subsector_id  \
# 0             1.144799      0.673259                    agrc - AG - Crops:CH4
# 1             2.938056      0.965996                    agrc - AG - Crops:CO2
# 2            29.452258      6.111167                    agrc - AG - Crops:N2O
# 3            44.017738      1.150861                lvst - AG - Livestock:CH4
# 4            44.017738      0.105391                lsmm - AG - Livestock:CH4
# ..                 ...           ...                                      ...
# 69           60.038853      0.588489           waso - Waste - Solid Waste:CH4
# 70            0.499233     18.401113           waso - Waste - Solid Waste:CO2
# 71            0.029932      0.041895           waso - Waste - Solid Waste:N2O
# 72           23.362827      5.803148  trww - Waste - Wastewater Treatment:CH4
# 73            2.078901      1.327745  trww - Waste - Wastewater Treatment:N2O
#
#     inventory_share
# 0          0.001792
# 1          0.004600
# 2          0.046112
# 3          0.068916
# 4          0.068916
# ..              ...
# 69         0.094000
# 70         0.000782
# 71         0.000047
# 72         0.036578
# 73         0.003255
#
# [74 rows x 4 columns]

# %%
# Calculate error column, avoid division by zero by adding a small constant to the denominator
epsilon = 1e-8
diff_report_df["error"] = (diff_report_df["ssp_emission"] - diff_report_df["inventory_emission"]).abs() / (diff_report_df["inventory_emission"] + epsilon)
diff_report_df["squared_error"] = (diff_report_df["error"] ** 2)
diff_report_df.head()
# Out:
#    inventory_emission  ssp_emission               subsector_id  \
# 0            1.144799      0.673259      agrc - AG - Crops:CH4
# 1            2.938056      0.965996      agrc - AG - Crops:CO2
# 2           29.452258      6.111167      agrc - AG - Crops:N2O
# 3           44.017738      1.150861  lvst - AG - Livestock:CH4
# 4           44.017738      0.105391  lsmm - AG - Livestock:CH4
#
#    inventory_share     error  squared_error
# 0         0.001792  0.411898       0.169660
# 1         0.004600  0.671212       0.450526
# 2         0.046112  0.792506       0.628066
# 3         0.068916  0.973855       0.948393
# 4         0.068916  0.997606       0.995217

# %%
# Set subsector_id at the beginning of the df
diff_report_df = diff_report_df[[
    "subsector_id",
    "inventory_emission",
    "ssp_emission",
    "inventory_share",
    "error",
    "squared_error"
]]

# sort by squared_error descending
diff_report_df = diff_report_df.sort_values(by="squared_error", ascending=False)
diff_report_df.head(10)
# Out:
#                                 subsector_id  inventory_emission  \
# 62  frst - LULUCF - Forest Land Removals:CO2            0.000000
# 64                   frst - LULUCF - HWP:CO2            0.000000
# 66          soil - LULUCF - Organic Soil:N2O            0.000000
# 65          soil - LULUCF - Organic Soil:CO2            0.000000
# 61           frst - LULUCF - Forest Land:CH4            0.000000
# 59         lndu - LULUCF - Deforestation:CH4            0.000000
# 57      ippu - IN - Industrial Processes:PFC            0.000000
# 68                    ippu - UNACCOUNTED:NF3            0.000000
# 70            waso - Waste - Solid Waste:CO2            0.499233
# 54      ippu - IN - Industrial Processes:HFC            0.751951
#
#     ssp_emission  inventory_share         error  squared_error
# 62     54.542412         0.000000  5.454241e+09   2.974875e+19
# 64    -53.859284         0.000000  5.385928e+09   2.900822e+19
# 66     18.148534         0.000000  1.814853e+09   3.293693e+18
# 65      7.591116         0.000000  7.591116e+08   5.762505e+17
# 61      1.880314         0.000000  1.880314e+08   3.535582e+16
# 59      0.855117         0.000000  8.551173e+07   7.312255e+15
# 57      0.472468         0.000000  4.724678e+07   2.232258e+15
# 68      0.000005         0.000000  4.772413e+02   2.277593e+05
# 70     18.401113         0.000782  3.585879e+01   1.285853e+03
# 54     25.164233         0.001177  3.246526e+01   1.053993e+03

# %%
diff_report_df.tail(40)
# Out:
#                                      subsector_id  inventory_emission  \
# 41           ippu - IN - Industrial Processes:HFC            0.751951
# 30           ippu - IN - Industrial Processes:HFC            0.751951
# 56           ippu - IN - Industrial Processes:HFC            0.751951
# 9                        scoe - EN - Building:CH4            1.856099
# 4                       lsmm - AG - Livestock:CH4           44.017738
# 11                       scoe - EN - Building:N2O            1.020252
# 69                 waso - Waste - Solid Waste:CH4           60.038853
# 3                       lvst - AG - Livestock:CH4           44.017738
# 5                       lsmm - AG - Livestock:N2O            1.719675
# 16             fgtv - EN - Fugitive Emissions:CO2           61.441517
# 31           ippu - IN - Industrial Processes:HFC            0.751951
# 17             fgtv - EN - Fugitive Emissions:N2O            0.071321
# 10                       scoe - EN - Building:CO2           33.640164
# 52           ippu - IN - Industrial Processes:HFC            0.751951
# 12               entc - EN - Electricity/Heat:CH4            0.156113
# 2                           agrc - AG - Crops:N2O           29.452258
# 72        trww - Waste - Wastewater Treatment:CH4           23.362827
# 27           ippu - IN - Industrial Processes:HFC            0.751951
# 24                 trns - EN - Transportation:CH4            0.746003
# 53           ippu - IN - Industrial Processes:CO2           57.589810
# 25                 trns - EN - Transportation:CO2          144.605110
# 1                           agrc - AG - Crops:CO2            2.938056
# 42           ippu - IN - Industrial Processes:HFC            0.751951
# 26                 trns - EN - Transportation:N2O            1.488377
# 15             fgtv - EN - Fugitive Emissions:CH4           26.074542
# 0                           agrc - AG - Crops:CH4            1.144799
# 13               entc - EN - Electricity/Heat:CO2          129.460961
# 19     inen - EN - Manufacturing/Construction:CO2           57.599161
# 71                 waso - Waste - Solid Waste:N2O            0.029932
# 43           ippu - IN - Industrial Processes:HFC            0.751951
# 73        trww - Waste - Wastewater Treatment:N2O            2.078901
# 63  frst - LULUCF - Forest Land Sequestration:CO2         -200.670000
# 14               entc - EN - Electricity/Heat:N2O            0.233475
# 55           ippu - IN - Industrial Processes:N2O           73.338456
# 23                          scoe - EN - Other:N2O            0.000000
# 22                          scoe - EN - Other:CO2            0.000000
# 21                          scoe - EN - Other:CH4            0.000000
# 8                                 ccsq - CCSQ:N2O            0.000000
# 7                                 ccsq - CCSQ:CO2            0.000000
# 6                                 ccsq - CCSQ:CH4            0.000000
#
#     ssp_emission  inventory_share     error  squared_error
# 41  4.726033e-07         0.001177  0.999999       0.999999
# 30  9.054895e-07         0.001177  0.999999       0.999998
# 56  5.262434e-06         0.001177  0.999993       0.999986
# 9   3.290353e-03         0.002906  0.998227       0.996458
# 4   1.053909e-01         0.068916  0.997606       0.995217
# 11  3.789435e-03         0.001597  0.996286       0.992585
# 69  5.884886e-01         0.094000  0.990198       0.980492
# 3   1.150861e+00         0.068916  0.973855       0.948393
# 5   5.916752e-02         0.002692  0.965594       0.932371
# 16  6.256881e+00         0.096196  0.898165       0.806701
# 31  9.342464e-02         0.001177  0.875757       0.766950
# 17  9.763544e-03         0.000112  0.863104       0.744948
# 10  5.205534e+00         0.052669  0.845258       0.714462
# 52  1.188112e-01         0.001177  0.841996       0.708957
# 12  2.857663e-01         0.000244  0.830512       0.689751
# 2   6.111167e+00         0.046112  0.792506       0.628066
# 72  5.803148e+00         0.036578  0.751608       0.564914
# 27  1.954321e-01         0.001177  0.740100       0.547748
# 24  1.980711e-01         0.001168  0.734490       0.539476
# 53  1.611281e+01         0.090165  0.720214       0.518709
# 25  4.232049e+01         0.226401  0.707338       0.500326
# 1   9.659964e-01         0.004600  0.671212       0.450526
# 42  2.770343e-01         0.001177  0.631579       0.398892
# 26  7.809429e-01         0.002330  0.475306       0.225916
# 15  1.374013e+01         0.040824  0.473044       0.223771
# 0   6.732585e-01         0.001792  0.411898       0.169660
# 13  7.618733e+01         0.202690  0.411503       0.169335
# 19  3.391446e+01         0.090180  0.411199       0.169084
# 71  4.189454e-02         0.000047  0.399658       0.159726
# 43  1.041418e+00         0.001177  0.384955       0.148191
# 73  1.327745e+00         0.003255  0.361324       0.130555
# 63 -1.492306e+02        -0.314179 -0.256338       0.065709
# 14  2.054572e-01         0.000366  0.120005       0.014401
# 55  6.859104e+01         0.114822  0.064733       0.004190
# 23  0.000000e+00         0.000000  0.000000       0.000000
# 22  0.000000e+00         0.000000  0.000000       0.000000
# 21  0.000000e+00         0.000000  0.000000       0.000000
# 8   0.000000e+00         0.000000  0.000000       0.000000
# 7   0.000000e+00         0.000000  0.000000       0.000000
# 6   0.000000e+00         0.000000  0.000000       0.000000

# %% [markdown]
# ### Save diff table

# %%
diff_report_df.to_csv(os.path.join(RUN_DIR_PATH, f"diff_report_{REGION_NAME}.csv"), index=False)
