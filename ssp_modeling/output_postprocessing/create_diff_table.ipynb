# %%
import pandas as pd
import numpy as np
import os

# %%
OUTPUT_POSTPROCESSING_DIR_PATH = os.getcwd()
SSP_MODELING_DIR_PATH = os.path.dirname(OUTPUT_POSTPROCESSING_DIR_PATH)
SSP_OUTPUT_DIR_PATH = os.path.join(SSP_MODELING_DIR_PATH, "ssp_run_output")
CW_DATA_DIR_PATH = os.path.join(OUTPUT_POSTPROCESSING_DIR_PATH, "data/inventory")

# %%
ISO3 = "MEX"
REGION_NAME = "mexico"
RUN_DIR_PATH = os.path.join(SSP_OUTPUT_DIR_PATH, "sisepuede_results_sisepuede_run_2026-01-14T20;01;32.026760")

# %% [markdown]
# ### Load emission targets and ssp outputs dfs

# %%
# Load emission targets
emission_targets_df = pd.read_csv(os.path.join(CW_DATA_DIR_PATH, "emission_targets_MEX_2023_ni.csv"))
emission_targets_df.head()
# Out:
#   subsector_ssp   mex_sector                              mex_subsector  gas  \
# 0          entc  [1] Energía  [1A] Actividades de quema del combustible  CH4
# 1          entc  [1] Energía  [1A] Actividades de quema del combustible  CO2
# 2          entc  [1] Energía  [1A] Actividades de quema del combustible  N2O
# 3          inen  [1] Energía  [1A] Actividades de quema del combustible  CH4
# 4          inen  [1] Energía  [1A] Actividades de quema del combustible  CO2
#
#                                               ID  \
# 0  [1A] Actividades de quema del combustible:CH4
# 1  [1A] Actividades de quema del combustible:CO2
# 2  [1A] Actividades de quema del combustible:N2O
# 3  [1A] Actividades de quema del combustible:CH4
# 4  [1A] Actividades de quema del combustible:CO2
#
#                                                 vars  \
# 0  emission_co2e_ch4_entc_generation_pp_biogas:em...
# 1  emission_co2e_co2_entc_bmass_processing_and_re...
# 2  emission_co2e_n2o_entc_generation_pp_biogas:em...
# 3  emission_co2e_ch4_inen_agriculture_and_livesto...
# 4  emission_co2e_co2_inen_bmass_agriculture_and_l...
#
#                                                ids         MEX  Unnamed: 8
# 0  1:[1A] Actividades de quema del combustible:CH4    0.301967           1
# 1  2:[1A] Actividades de quema del combustible:CO2  104.716574           2
# 2  3:[1A] Actividades de quema del combustible:N2O    0.575148           3
# 3  4:[1A] Actividades de quema del combustible:CH4    0.301967           4
# 4  5:[1A] Actividades de quema del combustible:CO2  104.716574           5

# %%
# Load output data
ssp_output_df = pd.read_csv(os.path.join(RUN_DIR_PATH, 
                                         "sisepuede_results_sisepuede_run_2026-01-14T20;01;32.026760_WIDE_INPUTS_OUTPUTS.csv"))
ssp_output_df.head()
# Out:
#    primary_id  region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  mexico            0                    915064.856804
# 1           0  mexico            1                    918810.740135
# 2           0  mexico            2                    920717.618856
# 3           0  mexico            3                    919218.668628
# 4           0  mexico            4                    913050.592580
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             1.262784e+07           382618.243688            1.861776e+06
# 1             1.267953e+07           384184.518789            1.869398e+06
# 2             1.270584e+07           384981.846521            1.873277e+06
# 3             1.268516e+07           384355.086900            1.870228e+06
# 4             1.260004e+07           381776.014600            1.857678e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     18564.054951         264919.969367
# 1                                     18640.048235         266004.438178
# 2                                     18678.733364         266556.497683
# 3                                     18648.323941         266122.537352
# 4                                     18523.191277         264336.820738
#
#    area_agrc_crops_other_annual  ...  \
# 0                  2.776487e+06  ...
# 1                  2.787853e+06  ...
# 2                  2.793639e+06  ...
# 3                  2.789091e+06  ...
# 4                  2.770376e+06  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                          5.565740               1.696694
# 1                                          6.132020               1.756926
# 2                                          9.709369               1.748638
# 3                                          8.912849               1.778275
# 4                                          6.907958               1.760671
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       0.812563                                9.341061
# 1                       1.027836                                9.361449
# 2                       0.985574                               10.143155
# 3                       1.017304                               10.775415
# 4                       0.972611                               11.296426
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 0.877022                 5.8079
# 1                 0.934484                 6.1346
# 2                 0.976767                 6.3900
# 3                 1.031504                 6.2848
# 4                 1.045168                 6.3662
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    62.069805                26.565546
# 1                    61.429500                27.559922
# 2                    62.709260                28.495376
# 3                    61.477270                29.327011
# 4                    63.360530                29.502182
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                              20.529640
# 1                              21.361121
# 2                              23.175588
# 3                              24.410027
# 4                              23.821076
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %% [markdown]
# ### Obtain the ssp output values in the emission targets format

# %%
def sum_vars_from_ssp_outputs(
    emission_targets_df: pd.DataFrame,
    ssp_outputs_df: pd.DataFrame,
    vars_col: str = "Vars",
    out_col: str = "ssp_total",
    record_missing_col: str | None = "missing_vars",
    ssp_filter: dict | None = None,
) -> pd.DataFrame:
    """
    For each row in emission_targets_df, split the colon-separated strings in `vars_col`,
    find those columns in ssp_outputs_df, sum their values (over rows & columns), and
    write the total to `out_col` in emission_targets_df.

    Parameters
    ----------
    emission_targets_df : DataFrame
        Must contain a string column `vars_col` with colon-separated names.
    ssp_outputs_df : DataFrame
        Wide table whose columns include the names referenced by `emission_targets_df[vars_col]`.
    vars_col : str
        Column in emission_targets_df with colon-separated variable names.
    out_col : str
        New column to create in emission_targets_df with totals from ssp_outputs_df.
    record_missing_col : str | None
        If provided, creates a column listing any missing vars for each row.
    df2_filter : dict | None
        Optional filters to reduce ssp_outputs_df before summing, e.g.
        {"region": "egypt", "time_period": 7}

    Returns
    -------
    DataFrame
        emission_targets_df with new column `out_col` (and `record_missing_col` if requested).
    """
    # Optionally filter ssp_outputs_df by key=value pairs (e.g., region/time_period)
    if ssp_filter:
        mask = pd.Series(True, index=ssp_outputs_df.index)
        for k, v in ssp_filter.items():
            mask &= (ssp_outputs_df[k] == v)
        ssp_view = ssp_outputs_df.loc[mask]
    else:
        ssp_view = ssp_outputs_df

    # Ensure we only operate on numeric data when summing
    numeric_cols = set(ssp_view.select_dtypes(include=[np.number]).columns)

    def _total_for_vars(vars_str: str):
        if pd.isna(vars_str) or not str(vars_str).strip():
            return np.nan, []

        # Split, strip, and deduplicate while preserving order
        raw = [s.strip() for s in str(vars_str).split(":") if s.strip()]
        seen = set()
        cols = [c for c in raw if not (c in seen or seen.add(c))]

        present = [c for c in cols if c in ssp_view.columns and c in numeric_cols]
        missing = [c for c in cols if c not in ssp_view.columns or c not in numeric_cols]

        if not present or ssp_view.empty:
            return np.nan, missing

        # Sum over all filtered rows & all present columns
        vals = ssp_view[present].to_numpy(dtype=float, copy=False)
        total = np.nansum(vals)
        return float(total), missing

    totals, missings = [], []
    for v in emission_targets_df[vars_col].astype("string"):
        total, missing = _total_for_vars(v)
        totals.append(total)
        missings.append(missing)

    emission_targets_df = emission_targets_df.copy()
    emission_targets_df[out_col] = totals
    if record_missing_col is not None:
        emission_targets_df[record_missing_col] = missings

    return emission_targets_df


# -----------------------------
# Example usage
# -----------------------------

# If DF2 has a single row for the target (e.g., region="egypt", a specific time_period):
# df2_filter = {"region": "egypt"}              # or {"region": "egypt", "time_period": 7}
# If you want to sum across all rows of DF2, set df2_filter = None.

# df1_result = sum_vars_from_df2(DF1, DF2, vars_col="Vars",
#                                out_col="DF2_total",
#                                record_missing_col="Missing_in_DF2",
#                                df2_filter={"region": "egypt"})
# print(df1_result.head())

# %%
ssp_output_df.head()
# Out:
#    primary_id  region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  mexico            0                    915064.856804
# 1           0  mexico            1                    918810.740135
# 2           0  mexico            2                    920717.618856
# 3           0  mexico            3                    919218.668628
# 4           0  mexico            4                    913050.592580
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             1.262784e+07           382618.243688            1.861776e+06
# 1             1.267953e+07           384184.518789            1.869398e+06
# 2             1.270584e+07           384981.846521            1.873277e+06
# 3             1.268516e+07           384355.086900            1.870228e+06
# 4             1.260004e+07           381776.014600            1.857678e+06
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     18564.054951         264919.969367
# 1                                     18640.048235         266004.438178
# 2                                     18678.733364         266556.497683
# 3                                     18648.323941         266122.537352
# 4                                     18523.191277         264336.820738
#
#    area_agrc_crops_other_annual  ...  \
# 0                  2.776487e+06  ...
# 1                  2.787853e+06  ...
# 2                  2.793639e+06  ...
# 3                  2.789091e+06  ...
# 4                  2.770376e+06  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                          5.565740               1.696694
# 1                                          6.132020               1.756926
# 2                                          9.709369               1.748638
# 3                                          8.912849               1.778275
# 4                                          6.907958               1.760671
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       0.812563                                9.341061
# 1                       1.027836                                9.361449
# 2                       0.985574                               10.143155
# 3                       1.017304                               10.775415
# 4                       0.972611                               11.296426
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 0.877022                 5.8079
# 1                 0.934484                 6.1346
# 2                 0.976767                 6.3900
# 3                 1.031504                 6.2848
# 4                 1.045168                 6.3662
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    62.069805                26.565546
# 1                    61.429500                27.559922
# 2                    62.709260                28.495376
# 3                    61.477270                29.327011
# 4                    63.360530                29.502182
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                              20.529640
# 1                              21.361121
# 2                              23.175588
# 3                              24.410027
# 4                              23.821076
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %%
emission_targets_df_extended = sum_vars_from_ssp_outputs(emission_targets_df, ssp_output_df, vars_col="vars",
                               out_col="ssp_emission",
                               record_missing_col="missing_in_ssp_outputs",
                               ssp_filter={"region": REGION_NAME, "primary_id": 0, "time_period": 7})

emission_targets_df_extended.head()
# Out:
#   subsector_ssp   mex_sector                              mex_subsector  gas  \
# 0          entc  [1] Energía  [1A] Actividades de quema del combustible  CH4
# 1          entc  [1] Energía  [1A] Actividades de quema del combustible  CO2
# 2          entc  [1] Energía  [1A] Actividades de quema del combustible  N2O
# 3          inen  [1] Energía  [1A] Actividades de quema del combustible  CH4
# 4          inen  [1] Energía  [1A] Actividades de quema del combustible  CO2
#
#                                               ID  \
# 0  [1A] Actividades de quema del combustible:CH4
# 1  [1A] Actividades de quema del combustible:CO2
# 2  [1A] Actividades de quema del combustible:N2O
# 3  [1A] Actividades de quema del combustible:CH4
# 4  [1A] Actividades de quema del combustible:CO2
#
#                                                 vars  \
# 0  emission_co2e_ch4_entc_generation_pp_biogas:em...
# 1  emission_co2e_co2_entc_bmass_processing_and_re...
# 2  emission_co2e_n2o_entc_generation_pp_biogas:em...
# 3  emission_co2e_ch4_inen_agriculture_and_livesto...
# 4  emission_co2e_co2_inen_bmass_agriculture_and_l...
#
#                                                ids         MEX  Unnamed: 8  \
# 0  1:[1A] Actividades de quema del combustible:CH4    0.301967           1
# 1  2:[1A] Actividades de quema del combustible:CO2  104.716574           2
# 2  3:[1A] Actividades de quema del combustible:N2O    0.575148           3
# 3  4:[1A] Actividades de quema del combustible:CH4    0.301967           4
# 4  5:[1A] Actividades de quema del combustible:CO2  104.716574           5
#
#    ssp_emission missing_in_ssp_outputs
# 0      1.142646                     []
# 1    111.189930                     []
# 2      0.319464                     []
# 3      0.510508                     []
# 4    182.859305                     []

# %% [markdown]
# ### Create diff report

# %%
# subset the emission targets to create the diff report template
diff_report_df = emission_targets_df_extended[[
    "mex_subsector",
    "ID",
    ISO3,
    "ssp_emission",
]].copy()
diff_report_df.head()
# Out:
#                                mex_subsector  \
# 0  [1A] Actividades de quema del combustible
# 1  [1A] Actividades de quema del combustible
# 2  [1A] Actividades de quema del combustible
# 3  [1A] Actividades de quema del combustible
# 4  [1A] Actividades de quema del combustible
#
#                                               ID         MEX  ssp_emission
# 0  [1A] Actividades de quema del combustible:CH4    0.301967      1.142646
# 1  [1A] Actividades de quema del combustible:CO2  104.716574    111.189930
# 2  [1A] Actividades de quema del combustible:N2O    0.575148      0.319464
# 3  [1A] Actividades de quema del combustible:CH4    0.301967      0.510508
# 4  [1A] Actividades de quema del combustible:CO2  104.716574    182.859305

# %%
# merge subsector an id into a single column for clarity
diff_report_df["subsector_id"] = diff_report_df["mex_subsector"] + " - " + diff_report_df["ID"]
diff_report_df = diff_report_df.drop(columns=["mex_subsector", "ID"])
diff_report_df.head()
# Out:
#           MEX  ssp_emission                                       subsector_id
# 0    0.301967      1.142646  [1A] Actividades de quema del combustible - [1...
# 1  104.716574    111.189930  [1A] Actividades de quema del combustible - [1...
# 2    0.575148      0.319464  [1A] Actividades de quema del combustible - [1...
# 3    0.301967      0.510508  [1A] Actividades de quema del combustible - [1...
# 4  104.716574    182.859305  [1A] Actividades de quema del combustible - [1...

# %%
#rename region column
diff_report_df = diff_report_df.rename(columns={ISO3: "inventory_emission"})
diff_report_df.head()
# Out:
#    inventory_emission  ssp_emission  \
# 0            0.301967      1.142646
# 1          104.716574    111.189930
# 2            0.575148      0.319464
# 3            0.301967      0.510508
# 4          104.716574    182.859305
#
#                                         subsector_id
# 0  [1A] Actividades de quema del combustible - [1...
# 1  [1A] Actividades de quema del combustible - [1...
# 2  [1A] Actividades de quema del combustible - [1...
# 3  [1A] Actividades de quema del combustible - [1...
# 4  [1A] Actividades de quema del combustible - [1...

# %%
# Create inventory_share column
diff_report_df["inventory_share"] = diff_report_df["inventory_emission"] / diff_report_df["inventory_emission"].sum()
diff_report_df
# Out:
#     inventory_emission  ssp_emission  \
# 0             0.301967      1.142646
# 1           104.716574    111.189930
# 2             0.575148      0.319464
# 3             0.301967      0.510508
# 4           104.716574    182.859305
# ..                 ...           ...
# 66           23.618549     16.475465
# 67            6.880253      9.317959
# 68            0.000000      0.000000
# 69            0.000000      0.000000
# 70            0.000000      0.000000
#
#                                          subsector_id  inventory_share
# 0   [1A] Actividades de quema del combustible - [1...         0.000551
# 1   [1A] Actividades de quema del combustible - [1...         0.191162
# 2   [1A] Actividades de quema del combustible - [1...         0.001050
# 3   [1A] Actividades de quema del combustible - [1...         0.000551
# 4   [1A] Actividades de quema del combustible - [1...         0.191162
# ..                                                ...              ...
# 66  [5D] Tratamiento y eliminación de aguas residu...         0.043116
# 67  [5D] Tratamiento y eliminación de aguas residu...         0.012560
# 68                             [6] CCSQ - [6] CCSQCH4         0.000000
# 69                             [6] CCSQ - [6] CCSQCO2         0.000000
# 70                             [6] CCSQ - [6] CCSQN2O         0.000000
#
# [71 rows x 4 columns]

# %%
# Calculate error column, avoid division by zero by adding a small constant to the denominator
epsilon = 1e-8
diff_report_df["error"] = (diff_report_df["ssp_emission"] - diff_report_df["inventory_emission"]).abs() / (diff_report_df["inventory_emission"] + epsilon)
diff_report_df["squared_error"] = (diff_report_df["error"] ** 2)
diff_report_df.head()
# Out:
#    inventory_emission  ssp_emission  \
# 0            0.301967      1.142646
# 1          104.716574    111.189930
# 2            0.575148      0.319464
# 3            0.301967      0.510508
# 4          104.716574    182.859305
#
#                                         subsector_id  inventory_share  \
# 0  [1A] Actividades de quema del combustible - [1...         0.000551
# 1  [1A] Actividades de quema del combustible - [1...         0.191162
# 2  [1A] Actividades de quema del combustible - [1...         0.001050
# 3  [1A] Actividades de quema del combustible - [1...         0.000551
# 4  [1A] Actividades de quema del combustible - [1...         0.191162
#
#       error  squared_error
# 0  2.784008       7.750702
# 1  0.061818       0.003821
# 2  0.444553       0.197628
# 3  0.690609       0.476941
# 4  0.746231       0.556860

# %%
# Set subsector_id at the beginning of the df
diff_report_df = diff_report_df[[
    "subsector_id",
    "inventory_emission",
    "ssp_emission",
    "inventory_share",
    "error",
    "squared_error"
]]

# sort by squared_error descending
diff_report_df = diff_report_df.sort_values(by="squared_error", ascending=False)
diff_report_df.head(10)
# Out:
#                                          subsector_id  inventory_emission  \
# 26  [2C] Industria de los metales - [2C] Industria...            0.000000
# 29  [2C] Industria de los metales - [2C] Industria...            0.000000
# 38                        [2H] Otros - [2H] Otros:CO2            0.031821
# 22  [2B] Industria química - [2B] Industria químic...            0.408147
# 64  [5C] Incineración y quema a cielo abierto de r...            2.077697
# 14  [1B] Emisiones fugitivas provenientes de la fa...            0.004261
# 57  [4G] Productos de madera recolectada - [4G] Pr...           -3.427530
# 56  [4G] Productos de madera recolectada - [4G] Pr...           -3.427530
# 52                  [4C] Praderas - [4C] Praderas:CO2           10.774531
# 30  [2D] Uso de productos no energéticos de combus...            0.004521
#
#     ssp_emission  inventory_share         error  squared_error
# 26      0.138076         0.000000  1.380764e+07   1.906509e+14
# 29      0.118971         0.000000  1.189714e+07   1.415419e+14
# 38      4.433376         0.000058  1.383235e+02   1.913338e+04
# 22     55.138909         0.000745  1.340956e+02   1.798162e+04
# 64     61.326295         0.003793  2.851647e+01   8.131892e+02
# 14      0.058469         0.000008  1.272248e+01   1.618616e+02
# 57    -42.853133        -0.006257 -1.150263e+01   1.323104e+02
# 56    -42.853133        -0.006257 -1.150263e+01   1.323104e+02
# 52    -59.506170         0.019669  6.522855e+00   4.254764e+01
# 30      0.032417         0.000008  6.170121e+00   3.807040e+01

# %%
diff_report_df.tail(40)
# Out:
#                                          subsector_id  inventory_emission  \
# 31  [2E] Industria electrónica - [2E] Industria el...            0.000633
# 8   [1A] Actividades de quema del combustible - [1...            0.575148
# 6   [1A] Actividades de quema del combustible - [1...            0.301967
# 46  [3F] Emisiones de quemado de biomasa en tierra...            0.641786
# 4   [1A] Actividades de quema del combustible - [1...          104.716574
# 48                  [3G] Encalado - [3G] Encalado:CO2            0.041502
# 44  [3D1] Emisiones directas de los N2O de los sue...           12.177959
# 17  [1B] Emisiones fugitivas provenientes de la fa...            0.004261
# 40  [3B] Gestión del estiércol - [3B] Gestión del ...           19.821297
# 3   [1A] Actividades de quema del combustible - [1...            0.301967
# 42  [3B5] Emisiones indirectas de los N2O de la ge...            1.756984
# 54        [4E] Asentamientos - [4E] Asentamientos:CO2            0.609445
# 15  [1B] Emisiones fugitivas provenientes de la fa...            9.534994
# 41  [3B] Gestión del estiércol - [3B] Gestión del ...            8.326694
# 18  [2A] Industria de los minerales - [2A] Industr...           30.148902
# 16  [1B] Emisiones fugitivas provenientes de la fa...            9.274769
# 2   [1A] Actividades de quema del combustible - [1...            0.575148
# 67  [5D] Tratamiento y eliminación de aguas residu...            6.880253
# 35  [2F] Uso de productos sustitutos de las sustan...           29.393236
# 66  [5D] Tratamiento y eliminación de aguas residu...           23.618549
# 5   [1A] Actividades de quema del combustible - [1...            0.575148
# 39  [3A] Fermentación entérica - [3A] Fermentación...           80.282859
# 50  [4A] Tierra forestales - [4A] Tierra forestale...         -181.504861
# 58  [4(IV)] Emisiones de GEI por quemado de biomas...            2.503766
# 45  [3D2] Emisiones indirectas de los N2O de los s...            6.472000
# 49  [3H] Aplicación de urea - [3H] Aplicación de u...            1.612279
# 62  [5B] Tratamiento biológico de los residuos sól...            0.069907
# 60  [5A] Eliminación de residuos sólidos - [5A] El...           34.471017
# 61  [5B] Tratamiento biológico de los residuos sól...            0.098485
# 1   [1A] Actividades de quema del combustible - [1...          104.716574
# 10  [1A] Actividades de quema del combustible - [1...          104.716574
# 19  [2B] Industria química - [2B] Industria químic...            0.175622
# 24  [2B] Industria química - [2B] Industria químic...            0.000000
# 25  [2B] Industria química - [2B] Industria químic...            0.000000
# 28  [2C] Industria de los metales - [2C] Industria...            0.000000
# 23  [2B] Industria química - [2B] Industria químic...            0.000000
# 36  [2G] Manufactura y utilización de otros produc...            0.000000
# 68                             [6] CCSQ - [6] CCSQCH4            0.000000
# 69                             [6] CCSQ - [6] CCSQCO2            0.000000
# 70                             [6] CCSQ - [6] CCSQN2O            0.000000
#
#     ssp_emission  inventory_share     error  squared_error
# 31      0.000058         0.000001  0.908201       0.824829
# 8       0.053781         0.001050  0.906492       0.821728
# 6       0.030379         0.000551  0.899396       0.808914
# 46      0.111058         0.001172  0.826955       0.683854
# 4     182.859305         0.191162  0.746231       0.556860
# 48      0.010974         0.000076  0.735572       0.541066
# 44     20.990733         0.022231  0.723666       0.523692
# 17      0.001234         0.000008  0.710314       0.504546
# 40      5.880514         0.036184  0.703323       0.494664
# 3       0.510508         0.000551  0.690609       0.476941
# 42      0.681127         0.003207  0.612331       0.374950
# 54      0.258743         0.001113  0.575445       0.331137
# 15     14.862216         0.017406  0.558702       0.312148
# 41      3.807023         0.015201  0.542793       0.294624
# 18     15.177350         0.055037  0.496587       0.246599
# 16      4.706399         0.016931  0.492559       0.242614
# 2       0.319464         0.001050  0.444553       0.197628
# 67      9.317959         0.012560  0.354305       0.125532
# 35     20.046080         0.053658  0.318004       0.101126
# 66     16.475465         0.043116  0.302435       0.091467
# 5       0.747227         0.001050  0.299192       0.089516
# 39     56.969034         0.146558  0.290396       0.084330
# 50   -152.342515        -0.331341 -0.160670       0.025815
# 58      2.105596         0.004571  0.159028       0.025290
# 45      7.491856         0.011815  0.157580       0.024831
# 49      1.366791         0.002943  0.152261       0.023184
# 62      0.060780         0.000128  0.130549       0.017043
# 60     31.202938         0.062928  0.094807       0.008988
# 61      0.104909         0.000180  0.065232       0.004255
# 1     111.189930         0.191162  0.061818       0.003821
# 10    103.495192         0.191162  0.011664       0.000136
# 19      0.174731         0.000321  0.005071       0.000026
# 24      0.000000         0.000000  0.000000       0.000000
# 25      0.000000         0.000000  0.000000       0.000000
# 28      0.000000         0.000000  0.000000       0.000000
# 23      0.000000         0.000000  0.000000       0.000000
# 36      0.000000         0.000000  0.000000       0.000000
# 68      0.000000         0.000000  0.000000       0.000000
# 69      0.000000         0.000000  0.000000       0.000000
# 70      0.000000         0.000000  0.000000       0.000000

# %% [markdown]
# ### Save diff table

# %%
diff_report_df.to_csv(os.path.join(RUN_DIR_PATH, f"diff_report_{REGION_NAME}.csv"), index=False, encoding='utf-8')
